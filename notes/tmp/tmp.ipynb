# %%
from sympy import Basic
from typing import Any
from sympy.core.relational import Relational

from math import cos, sin, radians
import sympy as sp

A = sp.symbols("A")
B = sp.symbols("B")
m, L = sp.symbols("m L")

F_B = B*sin(radians(30)) * 0.75
f_area = 80 * m

F_area:Relational = sp.integrate(f_area,(m,0,L))
F_moment:Relational = sp.integrate(f_area * m,(m,0,L))


subs_dict: dict[Any, float] = {L: 1.5}
total_force:Basic = F_area.subs(subs_dict)
# Out:
# 40*L**2
# 90.0000000000000
# 90.0
